# %% [markdown]
# # Knihovny

# %%
import json
import pandas as pd
from datetime import datetime, timedelta
import os

# %% [markdown]
# # Funkce

# %%
def create_dataframes_dict(bookmaker_names):
    # script_dir = os.path.dirname(os.path.realpath(__file__))
    dataframes_dict = {}
    for bookmaker_name in bookmaker_names:
        file_path = os.path.join(f"../data/data_{bookmaker_name}.json") # join(script_dir, f"../data/data_{bookmaker_name}.json")
        with open(file_path, 'r') as file:
            data = json.load(file)
        df = pd.DataFrame(data)[[
            'bookmaker_id',
            'bookmaker_name',
            'sport_name',
            'sport_detail',
            'country_name',
            'event_startTime',
            'participant_home_list',
            'participant_away_list',
            'participants_gender',
            'participants_age',
            'bet_1',
            'bet_0',
            'bet_2',
            'bet_10',
            'bet_02',
            'bet_12',
            'bet_11',
            'bet_22',
            'event_id',
            'event_url'
        ]].apply(lambda col: col.map(lambda x: tuple(x) if isinstance(x, list) else x)).drop_duplicates()
        df['event_startTime'] = pd.to_datetime(df['event_startTime'])
        df['bet_list'] = tuple(zip(df['bet_1'], df['bet_0'], df['bet_2'], df['bet_10'], df['bet_02'], df['bet_12'], df['bet_11'], df['bet_22']))
        dataframes_dict[bookmaker_name] = df.loc[df['sport_name'] != 'special'].reset_index(drop = True)
    return dataframes_dict

def filter_only_close_days(number_of_days, dataframes_dict):
    number_of_days = int(number_of_days)
    today = datetime.now()
    start_date = today.replace(hour=0, minute=0, second=0, microsecond=0)
    end_date = (today + timedelta(days = number_of_days)).replace(hour=23, minute=59, second=59)
    for bookmaker_name in dataframes_dict.keys():
        dataframes_dict[bookmaker_name] = dataframes_dict[bookmaker_name][
            (dataframes_dict[bookmaker_name]['event_startTime'] >= start_date) &
            (dataframes_dict[bookmaker_name]['event_startTime'] <= end_date)
        ]
    return dataframes_dict

def clean_participant_names(dataframes_dict, printIndexDrops = False):
    for bookmaker_name, df in dataframes_dict.items():
        indexes_to_drop = set()
        df['participant_home_list_smaller'] = None
        df['participant_away_list_smaller'] = None
        for idx, row in df.iterrows():
            match_df = df[
                (df['sport_name'] == row['sport_name']) &
                df['sport_detail'].apply(lambda x: x == row['sport_detail'] or x == 'other' or row['sport_detail'] == 'other') &
                df['country_name'].apply(lambda x: x == row['country_name'] or x == 'other' or row['country_name'] == 'other') &
                (df['event_startTime'] == row['event_startTime']) &
                df['participant_home_list'].apply(lambda x: bool(set(x) & set(row['participant_home_list']))) &
                df['participant_away_list'].apply(lambda x: bool(set(x) & set(row['participant_away_list']))) &
                (df['participants_gender'] == row['participants_gender']) &
                (df['participants_age'] == row['participants_age']) &
                (df['event_url'] != row['event_url'])
            ]
            if len(match_df) > 0:
                delete_home_list = tuple(set(item for sublist in match_df['participant_home_list'] for item in sublist))
                delete_away_list = tuple(set(item for sublist in match_df['participant_away_list'] for item in sublist))
                home_list = tuple([word for word in row['participant_home_list'] if word not in delete_home_list])
                away_list = tuple([word for word in row['participant_away_list'] if word not in delete_away_list])
                if home_list and away_list:
                    df.at[idx, 'participant_home_list_smaller'] = home_list
                    df.at[idx, 'participant_away_list_smaller'] = away_list
                else:
                    indexes_to_drop.add(idx)
        if printIndexDrops:
            print(bookmaker_name, indexes_to_drop)
        df.drop(index = indexes_to_drop, inplace = True)
        df['participant_home_list'] = df.apply(lambda row: row['participant_home_list_smaller'] if row['participant_home_list_smaller'] is not None else row['participant_home_list'], axis=1)
        df['participant_away_list'] = df.apply(lambda row: row['participant_away_list_smaller'] if row['participant_away_list_smaller'] is not None else row['participant_away_list'], axis=1)
        df.drop('participant_home_list_smaller', axis=1, inplace=True)
        df.drop('participant_away_list_smaller', axis=1, inplace=True)
        df.reset_index(drop = True, inplace = True)
    return dataframes_dict

def create_events_table(dataframes_dict, dropBets = True):
    df_all = pd.concat(dataframes_dict.values(), axis=0).reset_index(drop=True)
    bookmaker_names = dataframes_dict.keys()
    
    events = pd.DataFrame(columns=[
        'events_id',
        'bookmaker_list',
        'sport_name',
        'sport_detail',
        'country_name',
        'event_startTime',
        'participant_home_list',
        'participant_away_list',
        'participants_gender',
        'participants_age',
        'bet_dict',
        'event_id_dict',
        'event_url_dict'
    ])
    errors = []
        
    for idx, row in df_all.iterrows():

        url_events = events[events['event_url_dict'].apply(lambda x: row['event_url'] in x.values())]
        if url_events.empty: # url tohoto zapasu jeste neni v tabulce events
            isError = False

            sport_detail = row['sport_detail']
            country_name = row['country_name']
            participant_home_list = row['participant_home_list']
            participant_away_list = row['participant_away_list']
            bet_dict = {item: tuple() for item in bookmaker_names}
            bet_dict[row['bookmaker_name']] = row['bet_list']
            event_id_dict = {item: None for item in bookmaker_names}
            event_id_dict[row['bookmaker_name']] = row['event_id']
            event_url_dict = {item: None for item in bookmaker_names}
            event_url_dict[row['bookmaker_name']] = row['event_url']

            bookmaker_search_dict = {item: False for item in bookmaker_names}
            bookmaker_search_dict[row['bookmaker_name']] = True
            not_searched_bookmakers_list = [key for key, value in bookmaker_search_dict.items() if value is False]

            while not_searched_bookmakers_list:
                bookmaker_name_searching = not_searched_bookmakers_list[0]
                bookmaker_df_searching = dataframes_dict[bookmaker_name_searching]
                match_df = bookmaker_df_searching[
                    (bookmaker_df_searching['sport_name'] == row['sport_name']) &
                    bookmaker_df_searching['sport_detail'].apply(lambda x: x == sport_detail or x == 'other' or sport_detail == 'other') &
                    bookmaker_df_searching['country_name'].apply(lambda x: x == country_name or x == 'other' or country_name == 'other') &
                    (bookmaker_df_searching['event_startTime'] == row['event_startTime']) &
                    bookmaker_df_searching['participant_home_list'].apply(lambda x: bool(set(x) & set(participant_home_list))) &
                    bookmaker_df_searching['participant_away_list'].apply(lambda x: bool(set(x) & set(participant_away_list))) &
                    (bookmaker_df_searching['participants_gender'] == row['participants_gender']) &
                    (bookmaker_df_searching['participants_age'] == row['participants_age'])
                ]
                if len(match_df) == 0: # v prohledavane tabulce nemame shodu
                    bookmaker_search_dict[bookmaker_name_searching] = True
                    not_searched_bookmakers_list = [key for key, value in bookmaker_search_dict.items() if value is False]
                elif len(match_df) == 1: # v prohledavane tabulce mame prave jednu shodu
                    match = match_df.iloc[0]
                    if sport_detail == 'other':
                        sport_detail = match['sport_detail']
                    if country_name == 'other':
                        country_name = match['country_name']
                    participant_home_list = tuple(set(participant_home_list + match['participant_home_list']))
                    participant_away_list = tuple(set(participant_away_list + match['participant_away_list']))
                    bet_dict[bookmaker_name_searching] = match['bet_list']
                    event_id_dict[bookmaker_name_searching] = match['event_id']
                    event_url_dict[bookmaker_name_searching] = match['event_url']
                    bookmaker_search_dict = {key: (value is not None) for key, value in event_url_dict.items()}
                    not_searched_bookmakers_list = [key for key, value in bookmaker_search_dict.items() if value is False]
                else: # v prohledavane tabulce mame vice nez jednu shodu -> error
                    error_dict = {
                        'sport_name': row['sport_name'],
                        'sport_detail': sport_detail,
                        'country_name': country_name,
                        'event_startTime': row['event_startTime'],
                        'participant_home_list': participant_home_list,
                        'participant_away_list': participant_away_list,
                        'participants_gender': row['participants_gender'],
                        'participants_age': row['participants_age'],
                        'event_id_dict': event_id_dict,
                        'event_url_dict': event_url_dict,
                        'match_df': match_df
                    }
                    errors.append(error_dict)

                    isError = True
                    event_url_dict[bookmaker_name_searching] = 'error'
                    bookmaker_search_dict[bookmaker_name_searching] = True
                    not_searched_bookmakers_list = [key for key, value in bookmaker_search_dict.items() if value is False]
                    for error_idx, error_row in match_df.iterrows():
                        new_error_row = {
                            'events_id': 'error',
                            'bookmaker_list': ('error',),
                            'sport_name': error_row['sport_name'],
                            'sport_detail': error_row['sport_detail'],
                            'country_name': error_row['country_name'],
                            'event_startTime': error_row['event_startTime'],
                            'participant_home_list': error_row['participant_home_list'],
                            'participant_away_list': error_row['participant_away_list'],
                            'participants_gender': error_row['participants_gender'],
                            'participants_age': error_row['participants_age'],
                            'bet_dict': {item: tuple() for item in bookmaker_names},
                            'event_id_dict': {item: None for item in bookmaker_names},
                            'event_url_dict': {item: None for item in bookmaker_names}
                        }
                        new_error_row['bet_dict'][bookmaker_name_searching] = error_row['bet_list']
                        new_error_row['event_id_dict'][bookmaker_name_searching] = error_row['event_id']
                        new_error_row['event_url_dict'][bookmaker_name_searching] = error_row['event_url']
                        new_error_row_df = pd.DataFrame([new_error_row])
                        events = pd.concat([events, new_error_row_df], ignore_index=True)
            if isError:
                bookmaker_list = ('error',)
            else:
                bookmaker_list = tuple([key for key, value in event_url_dict.items() if value is not None])
            events_id = '_'.join([item for item in event_id_dict.values() if item is not None])
            new_row = {
                'events_id': events_id,
                'bookmaker_list': bookmaker_list,
                'sport_name': row['sport_name'],
                'sport_detail': sport_detail,
                'country_name': country_name,
                'event_startTime': row['event_startTime'],
                'participant_home_list': participant_home_list,
                'participant_away_list': participant_away_list,
                'participants_gender': row['participants_gender'],
                'participants_age': row['participants_age'],
                'bet_dict': bet_dict,
                'event_id_dict': event_id_dict,
                'event_url_dict': event_url_dict
            }
            new_row_df = pd.DataFrame([new_row])
            # events = pd.concat([events, new_row_df], ignore_index=True)
            dfs_to_concat = [df for df in [events, new_row_df] if not df.empty and not df.isna().all().all()]
            events = pd.concat(dfs_to_concat, ignore_index=True)
    
    if dropBets:
        events.drop('bet_dict', axis=1, inplace=True)
        events.reset_index(drop = True, inplace = True)
    return events

# %% [markdown]
# # Main

# %%
# import subprocess


# subprocess.run(["python", "crawler.py"])

# %%
# nahrat puvodni data o eventech do dataframu

bookmaker_names = ['betano', 'betx', 'forbet', 'fortuna', 'kingsbet', 'merkur', 'sazka', 'synottip', 'tipsport']
dataframes_dict = create_dataframes_dict(bookmaker_names)

# %%
# vyfiltrovat pouze omezeny pocet dnu nasledujicihc po dnu stazeni dat

number_of_days = 0
dataframes_dict = filter_only_close_days(number_of_days, dataframes_dict)

# %%
# vycistit slova navic v listech obsahujicich jmena jednotlivych tymu

printIndexDrops = False
dataframes_dict = clean_participant_names(dataframes_dict, printIndexDrops)

# %%
# vytvorit dataframe obsahujici vsechny puvodni eventy

# df_all = pd.concat(dataframes_dict.values(), axis=0).reset_index(drop=True)
# len(df_all)

# %%
# vytvorit spojenou tabulku pro vsechny puvodni eventy

dropBets = True
events = create_events_table(dataframes_dict, dropBets)

# %%
# oddelit eventy s errorem

# events_with_error = events[events['bookmaker_list'].apply(lambda x: 'error' in x)]
events = events[~events['bookmaker_list'].apply(lambda x: 'error' in x)]

# %%
# oddelit eventy, ktere se na nic nenapoji

# events_singlies = events[events['bookmaker_list'].apply(lambda x: len(x) == 1)]
events = events[~events['bookmaker_list'].apply(lambda x: len(x) == 1)]

# %%
lists_for_detail_spiders_dict = {}
for bookmaker_name in bookmaker_names:
    lists_for_detail_spiders_dict[bookmaker_name] = []
for sport_name, event_url_dict in zip(events['sport_name'], events['event_url_dict']):
    for bookmaker_name, event_url in event_url_dict.items():
        if event_url is not None:
            lists_for_detail_spiders_dict[bookmaker_name].append({
                'sport_name': sport_name,
                'event_url': event_url
            })

# %%
from scrapy.crawler import CrawlerProcess
from scrapy.settings import Settings
from betscraper.spiders import spider_betano_detail, spider_betx_detail, spider_forbet_detail, spider_fortuna_detail, spider_kingsbet_detail, spider_merkur_detail, spider_sazka_detail, spider_synottip_detail, spider_tipsport_detail
# from betscraper.spiders import spider_livescore


settings = Settings()
settings.setmodule('betscraper.settings', priority='project')
process = CrawlerProcess(settings)

process.crawl(spider_betano_detail.SpiderBetanoDetailSpider, arg_data = lists_for_detail_spiders_dict['betano']) #, arg_sport_name = sport_name, arg_events_limit = events_limit) #, arg_event_url = 'https://www.betano.cz/zapas-sance/teplice-sk-slavia-praha/58204893/')
process.crawl(spider_betx_detail.SpiderBetxDetailSpider, arg_data = lists_for_detail_spiders_dict['betx']) #, arg_sport_name = sport_name, arg_events_limit = events_limit) #, arg_event_url = 'https://bet-x.cz/cs/sports-betting/offer/soccer?match=50936435')
process.crawl(spider_forbet_detail.SpiderForbetDetailSpider, arg_data = lists_for_detail_spiders_dict['forbet']) #, arg_sport_name = sport_name, arg_events_limit = events_limit) #, arg_event_url = 'https://www.fbet.cz/prematch/event/MA50936435')
process.crawl(spider_fortuna_detail.SpiderFortunaDetailSpider, arg_data = lists_for_detail_spiders_dict['fortuna']) #, arg_sport_name = sport_name, arg_events_limit = events_limit) #, arg_event_url = 'https://www.ifortuna.cz/sazeni/fotbal/1-cesko/teplice-slavia-praha-MCZ149614999')
process.crawl(spider_kingsbet_detail.SpiderKingsbetDetailSpider, arg_data = lists_for_detail_spiders_dict['kingsbet']) #, arg_sport_name = sport_name, arg_events_limit = events_limit) #, arg_event_url = 'https://www.kingsbet.cz/sport?page=event&eventId=10301025')
process.crawl(spider_merkur_detail.SpiderMerkurDetailSpider, arg_data = lists_for_detail_spiders_dict['merkur']) #, arg_sport_name = sport_name, arg_events_limit = events_limit) #, arg_event_url = 'https://www.merkurxtip.cz/sazeni/online/fotbal/S/1-liga/2334015/special/teplice-v-slavia-prague/130050705')
process.crawl(spider_sazka_detail.SpiderSazkaDetailSpider, arg_data = lists_for_detail_spiders_dict['sazka']) #, arg_sport_name = sport_name, arg_events_limit = events_limit) #, arg_event_url = 'https://www.sazka.cz/kurzove-sazky/sports/event/1818260')
process.crawl(spider_synottip_detail.SpiderSynottipDetailSpider, arg_data = lists_for_detail_spiders_dict['synottip']) #, arg_sport_name = sport_name, arg_events_limit = events_limit) #, arg_event_url = 'https://sport.synottip.cz/zapasy/12cx13cxx27/2416017cxx27/241943424?categoryId=12cx13cxx27')
process.crawl(spider_tipsport_detail.SpiderTipsportDetailSpider, arg_data = lists_for_detail_spiders_dict['tipsport']) #, arg_sport_name = sport_name, arg_events_limit = events_limit) #, arg_event_url = 'https://www.tipsport.cz/kurzy/zapas/fotbal-teplice-slavia-praha/6215185')

process.start()
# Out:
# 2024-12-19 01:26:55 [scrapy.utils.log] INFO: Scrapy 2.11.2 started (bot: betscraper)
# 2024-12-19 01:26:55 [scrapy.utils.log] INFO: Versions: lxml 5.2.2.0, libxml2 2.12.6, cssselect 1.2.0, parsel 1.9.1, w3lib 2.2.1, Twisted 24.3.0, Python 3.11.9 (main, Apr 19 2024, 16:48:06) [GCC 11.2.0], pyOpenSSL 24.2.1 (OpenSSL 3.3.1 4 Jun 2024), cryptography 43.0.0, Platform Linux-5.15.153.1-microsoft-standard-WSL2-x86_64-with-glibc2.35
# 2024-12-19 01:26:55 [scrapy.addons] INFO: Enabled addons:
# []
# 2024-12-19 01:26:55 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.asyncioreactor.AsyncioSelectorReactor
# 2024-12-19 01:26:55 [scrapy.utils.log] DEBUG: Using asyncio event loop: asyncio.unix_events._UnixSelectorEventLoop
# 2024-12-19 01:26:55 [scrapy.extensions.telnet] INFO: Telnet Password: 36d50b6a4103588a
# 2024-12-19 01:26:58 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2024-12-19 01:26:58 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'betscraper',
#  'CONCURRENT_REQUESTS': 512,
#  'CONCURRENT_REQUESTS_PER_DOMAIN': 512,
#  'FEED_EXPORT_ENCODING': 'utf-8',
#  'NEWSPIDER_MODULE': 'betscraper.spiders',
#  'REQUEST_FINGERPRINTER_IMPLEMENTATION': '2.7',
#  'SPIDER_MODULES': ['betscraper.spiders'],
#  'TWISTED_REACTOR': 'twisted.internet.asyncioreactor.AsyncioSelectorReactor',
#  'USER_AGENT': 'Mozilla/5.0 (X11; Linux x86_64; rv:34.0) Gecko/20100101 '
#                'Firefox/34.0'}
# 2024-12-19 01:26:59 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2024-12-19 01:26:59 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2024-12-19 01:26:59 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2024-12-19 01:26:59 [scrapy.core.engine] INFO: Spider opened
# 2024-12-19 01:26:59 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2024-12-19 01:26:59 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2024-12-19 01:26:59 [scrapy.addons] INFO: Enabled addons:
# []
# 2024-12-19 01:26:59 [scrapy.extensions.telnet] INFO: Telnet Password: e91b1fd08c0a08b1
# 2024-12-19 01:26:59 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2024-12-19 01:26:59 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'betscraper',
#  'CONCURRENT_REQUESTS': 32,
#  'CONCURRENT_REQUESTS_PER_DOMAIN': 32,
#  'FEED_EXPORT_ENCODING': 'utf-8',
#  'NEWSPIDER_MODULE': 'betscraper.spiders',
#  'REQUEST_FINGERPRINTER_IMPLEMENTATION': '2.7',
#  'SPIDER_MODULES': ['betscraper.spiders'],
#  'TWISTED_REACTOR': 'twisted.internet.asyncioreactor.AsyncioSelectorReactor',
#  'USER_AGENT': 'Mozilla/5.0 (X11; Linux x86_64; rv:34.0) Gecko/20100101 '
#                'Firefox/34.0'}
# 2024-12-19 01:26:59 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2024-12-19 01:26:59 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2024-12-19 01:26:59 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2024-12-19 01:26:59 [scrapy.core.engine] INFO: Spider opened
# 2024-12-19 01:26:59 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2024-12-19 01:26:59 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6024
# 2024-12-19 01:26:59 [scrapy.addons] INFO: Enabled addons:
# []
# 2024-12-19 01:26:59 [scrapy.extensions.telnet] INFO: Telnet Password: 89302b67df251dc6
# 2024-12-19 01:26:59 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2024-12-19 01:26:59 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'betscraper',
#  'CONCURRENT_REQUESTS': 32,
#  'CONCURRENT_REQUESTS_PER_DOMAIN': 32,
#  'FEED_EXPORT_ENCODING': 'utf-8',
#  'NEWSPIDER_MODULE': 'betscraper.spiders',
#  'REQUEST_FINGERPRINTER_IMPLEMENTATION': '2.7',
#  'SPIDER_MODULES': ['betscraper.spiders'],
#  'TWISTED_REACTOR': 'twisted.internet.asyncioreactor.AsyncioSelectorReactor'}
# 2024-12-19 01:26:59 [urllib3.connectionpool] DEBUG: Starting new HTTPS connection (1): headers.scrapeops.io:443
# 2024-12-19 01:26:59 [urllib3.connectionpool] DEBUG: https://headers.scrapeops.io:443 "GET /v1/user-agents?api_key=60bc6d8b-70a1-43df-918f-94c906fd2562&num_results=5 HTTP/11" 200 606
# 2024-12-19 01:26:59 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'betscraper.middlewares.ScrapeOpsFakeUserAgentMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2024-12-19 01:26:59 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2024-12-19 01:26:59 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2024-12-19 01:26:59 [scrapy.core.engine] INFO: Spider opened
# 2024-12-19 01:26:59 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2024-12-19 01:26:59 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6025
# 2024-12-19 01:26:59 [scrapy.addons] INFO: Enabled addons:
# []
# 2024-12-19 01:26:59 [scrapy.extensions.telnet] INFO: Telnet Password: 490461bf325e510d
# 2024-12-19 01:26:59 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2024-12-19 01:26:59 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'betscraper',
#  'CONCURRENT_REQUESTS': 64,
#  'CONCURRENT_REQUESTS_PER_DOMAIN': 64,
#  'FEED_EXPORT_ENCODING': 'utf-8',
#  'NEWSPIDER_MODULE': 'betscraper.spiders',
#  'REQUEST_FINGERPRINTER_IMPLEMENTATION': '2.7',
#  'SPIDER_MODULES': ['betscraper.spiders'],
#  'TWISTED_REACTOR': 'twisted.internet.asyncioreactor.AsyncioSelectorReactor',
#  'USER_AGENT': 'Mozilla/5.0 (X11; Linux x86_64; rv:34.0) Gecko/20100101 '
#                'Firefox/34.0'}
# 2024-12-19 01:26:59 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2024-12-19 01:26:59 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2024-12-19 01:26:59 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2024-12-19 01:26:59 [scrapy.core.engine] INFO: Spider opened
# 2024-12-19 01:26:59 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2024-12-19 01:26:59 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6026
# 2024-12-19 01:26:59 [scrapy.addons] INFO: Enabled addons:
# []
# 2024-12-19 01:26:59 [scrapy.extensions.telnet] INFO: Telnet Password: 2831bbae49c5372f
# 2024-12-19 01:26:59 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2024-12-19 01:26:59 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'betscraper',
#  'CONCURRENT_REQUESTS': 32,
#  'CONCURRENT_REQUESTS_PER_DOMAIN': 32,
#  'FEED_EXPORT_ENCODING': 'utf-8',
#  'NEWSPIDER_MODULE': 'betscraper.spiders',
#  'REQUEST_FINGERPRINTER_IMPLEMENTATION': '2.7',
#  'SPIDER_MODULES': ['betscraper.spiders'],
#  'TWISTED_REACTOR': 'twisted.internet.asyncioreactor.AsyncioSelectorReactor',
#  'USER_AGENT': 'Mozilla/5.0 (X11; Linux x86_64; rv:34.0) Gecko/20100101 '
#                'Firefox/34.0'}
# 2024-12-19 01:26:59 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2024-12-19 01:26:59 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2024-12-19 01:26:59 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2024-12-19 01:26:59 [scrapy.core.engine] INFO: Spider opened
# 2024-12-19 01:26:59 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2024-12-19 01:26:59 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6027
# 2024-12-19 01:26:59 [scrapy.addons] INFO: Enabled addons:
# []
# 2024-12-19 01:26:59 [scrapy.extensions.telnet] INFO: Telnet Password: 3788c7a658657c5c
# 2024-12-19 01:26:59 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2024-12-19 01:26:59 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'betscraper',
#  'CONCURRENT_REQUESTS': 32,
#  'CONCURRENT_REQUESTS_PER_DOMAIN': 32,
#  'FEED_EXPORT_ENCODING': 'utf-8',
#  'NEWSPIDER_MODULE': 'betscraper.spiders',
#  'REQUEST_FINGERPRINTER_IMPLEMENTATION': '2.7',
#  'SPIDER_MODULES': ['betscraper.spiders'],
#  'TWISTED_REACTOR': 'twisted.internet.asyncioreactor.AsyncioSelectorReactor'}
# 2024-12-19 01:26:59 [urllib3.connectionpool] DEBUG: Starting new HTTPS connection (1): headers.scrapeops.io:443
# 2024-12-19 01:27:00 [urllib3.connectionpool] DEBUG: https://headers.scrapeops.io:443 "GET /v1/browser-headers?api_key=60bc6d8b-70a1-43df-918f-94c906fd2562&num_results=5 HTTP/11" 200 2974
# 2024-12-19 01:27:00 [urllib3.connectionpool] DEBUG: Starting new HTTPS connection (1): headers.scrapeops.io:443
# 2024-12-19 01:27:00 [urllib3.connectionpool] DEBUG: https://headers.scrapeops.io:443 "GET /v1/user-agents?api_key=60bc6d8b-70a1-43df-918f-94c906fd2562&num_results=5 HTTP/11" 200 594
# 2024-12-19 01:27:00 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'betscraper.middlewares.ScrapeOpsFakeBrowserHeaderAgentMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'betscraper.middlewares.ScrapeOpsFakeUserAgentMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapeops_scrapy.middleware.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2024-12-19 01:27:00 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2024-12-19 01:27:00 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2024-12-19 01:27:00 [scrapy.core.engine] INFO: Spider opened
# 2024-12-19 01:27:00 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2024-12-19 01:27:00 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6028
# 2024-12-19 01:27:00 [scrapy.addons] INFO: Enabled addons:
# []
# 2024-12-19 01:27:00 [scrapy.extensions.telnet] INFO: Telnet Password: 8d542c13d3d2eff5
# 2024-12-19 01:27:00 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2024-12-19 01:27:00 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'betscraper',
#  'CONCURRENT_REQUESTS': 64,
#  'CONCURRENT_REQUESTS_PER_DOMAIN': 64,
#  'FEED_EXPORT_ENCODING': 'utf-8',
#  'NEWSPIDER_MODULE': 'betscraper.spiders',
#  'REQUEST_FINGERPRINTER_IMPLEMENTATION': '2.7',
#  'SPIDER_MODULES': ['betscraper.spiders'],
#  'TWISTED_REACTOR': 'twisted.internet.asyncioreactor.AsyncioSelectorReactor',
#  'USER_AGENT': 'Mozilla/5.0 (X11; Linux x86_64; rv:34.0) Gecko/20100101 '
#                'Firefox/34.0'}
# 2024-12-19 01:27:00 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2024-12-19 01:27:00 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2024-12-19 01:27:00 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2024-12-19 01:27:00 [scrapy.core.engine] INFO: Spider opened
# 2024-12-19 01:27:00 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2024-12-19 01:27:00 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6029
# 2024-12-19 01:27:00 [scrapy.addons] INFO: Enabled addons:
# []
# 2024-12-19 01:27:00 [scrapy.extensions.telnet] INFO: Telnet Password: bd5c18cf5972dcdc
# 2024-12-19 01:27:00 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2024-12-19 01:27:00 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'betscraper',
#  'CONCURRENT_REQUESTS': 32,
#  'CONCURRENT_REQUESTS_PER_DOMAIN': 32,
#  'FEED_EXPORT_ENCODING': 'utf-8',
#  'NEWSPIDER_MODULE': 'betscraper.spiders',
#  'REQUEST_FINGERPRINTER_IMPLEMENTATION': '2.7',
#  'SPIDER_MODULES': ['betscraper.spiders'],
#  'TWISTED_REACTOR': 'twisted.internet.asyncioreactor.AsyncioSelectorReactor',
#  'USER_AGENT': 'Mozilla/5.0 (X11; Linux x86_64; rv:34.0) Gecko/20100101 '
#                'Firefox/34.0'}
# 2024-12-19 01:27:00 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2024-12-19 01:27:00 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2024-12-19 01:27:00 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2024-12-19 01:27:00 [scrapy.core.engine] INFO: Spider opened
# 2024-12-19 01:27:00 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2024-12-19 01:27:00 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6030
# 2024-12-19 01:27:00 [scrapy.addons] INFO: Enabled addons:
# []
# 2024-12-19 01:27:00 [scrapy.extensions.telnet] INFO: Telnet Password: 30a5d3bf809f883b
# 2024-12-19 01:27:00 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2024-12-19 01:27:00 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'betscraper',
#  'FEED_EXPORT_ENCODING': 'utf-8',
#  'NEWSPIDER_MODULE': 'betscraper.spiders',
#  'REQUEST_FINGERPRINTER_IMPLEMENTATION': '2.7',
#  'SPIDER_MODULES': ['betscraper.spiders'],
#  'TWISTED_REACTOR': 'twisted.internet.asyncioreactor.AsyncioSelectorReactor',
#  'USER_AGENT': 'Mozilla/5.0 (X11; Linux x86_64; rv:34.0) Gecko/20100101 '
#                'Firefox/34.0'}
# 2024-12-19 01:27:01 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2024-12-19 01:27:01 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2024-12-19 01:27:01 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2024-12-19 01:27:01 [scrapy.core.engine] INFO: Spider opened
# 2024-12-19 01:27:01 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2024-12-19 01:27:01 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6031
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[14], line 21
#      18 process.crawl(spider_synottip_detail.SpiderSynottipDetailSpider, arg_data = lists_for_detail_spiders_dict['synottip']) #, arg_sport_name = sport_name, arg_events_limit = events_limit) #, arg_event_url = 'https://sport.synottip.cz/zapasy/12cx13cxx27/2416017cxx27/241943424?categoryId=12cx13cxx27')
#      19 process.crawl(spider_tipsport_detail.SpiderTipsportDetailSpider, arg_data = lists_for_detail_spiders_dict['tipsport']) #, arg_sport_name = sport_name, arg_events_limit = events_limit) #, arg_event_url = 'https://www.tipsport.cz/kurzy/zapas/fotbal-teplice-slavia-praha/6215185')
# ---> 21 process.start()
#
# File /mnt/c/Users/adamr/VSCodeProjects/BetScraper/bet_scraper/.conda/lib/python3.11/site-packages/scrapy/crawler.py:429, in CrawlerProcess.start(self, stop_after_crawl, install_signal_handlers)
#     425 if install_signal_handlers:
#     426     reactor.addSystemEventTrigger(
#     427         "after", "startup", install_shutdown_handlers, self._signal_shutdown
#     428     )
# --> 429 reactor.run(installSignalHandlers=install_signal_handlers)
#
# File /mnt/c/Users/adamr/VSCodeProjects/BetScraper/bet_scraper/.conda/lib/python3.11/site-packages/twisted/internet/asyncioreactor.py:253, in AsyncioSelectorReactor.run(self, installSignalHandlers)
#     251 def run(self, installSignalHandlers=True):
#     252     self.startRunning(installSignalHandlers=installSignalHandlers)
# --> 253     self._asyncioEventloop.run_forever()
#     254     if self._justStopped:
#     255         self._justStopped = False
#
# File /mnt/c/Users/adamr/VSCodeProjects/BetScraper/bet_scraper/.conda/lib/python3.11/asyncio/base_events.py:597, in BaseEventLoop.run_forever(self)
#     595 """Run until stop() is called."""
#     596 self._check_closed()
# --> 597 self._check_running()
#     598 self._set_coroutine_origin_tracking(self._debug)
#     600 old_agen_hooks = sys.get_asyncgen_hooks()
#
# File /mnt/c/Users/adamr/VSCodeProjects/BetScraper/bet_scraper/.conda/lib/python3.11/asyncio/base_events.py:589, in BaseEventLoop._check_running(self)
#     587 def _check_running(self):
#     588     if self.is_running():
# --> 589         raise RuntimeError('This event loop is already running')
#     590     if events._get_running_loop() is not None:
#     591         raise RuntimeError(
#     592             'Cannot run the event loop while another loop is running')
#
# RuntimeError: This event loop is already running
# 2024-12-19 01:27:03 [scrapy-playwright] INFO: Starting download handler
# 2024-12-19 01:27:03 [scrapy-playwright] INFO: Starting download handler
# 2024-12-19 01:27:03 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.betano.cz/api/zapas-sance/sultanes-de-monterrey-naranjeros-de-hermosillo/60402963/?bt=99&req=la,t,s,stnf,c,mb,mbl> (referer: None)
# 2024-12-19 01:27:03 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.betano.cz/api/zapas-sance/tomateros-de-culiacan-mayos-de-navojoa/60330626/?bt=99&req=la,t,s,stnf,c,mb,mbl> (referer: None)
# 2024-12-19 01:27:03 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sb2frontend-altenar2.biahosted.com/api/widget/GetEventDetails?culture=cs-CZ&timezoneOffset=-60&integration=kingsbet&deviceType=1&numFormat=en-GB&countryCode=CZ&eventId=10354195> (referer: None)
# 2024-12-19 01:27:03 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sb2frontend-altenar2.biahosted.com/api/widget/GetEventDetails?culture=cs-CZ&timezoneOffset=-60&integration=kingsbet&deviceType=1&numFormat=en-GB&countryCode=CZ&eventId=11048953> (referer: None)
# 2024-12-19 01:27:03 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.betano.cz/api/zapas-sance/algodonerose-guasave-yaquis-de-obregon/60402930/?bt=99&req=la,t,s,stnf,c,mb,mbl> (referer: None)
# 2024-12-19 01:27:03 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.betano.cz/api/zapas-sance/caneros-de-los-mochis-aguilas-de-mexicali/60402941/?bt=99&req=la,t,s,stnf,c,mb,mbl> (referer: None)
# 2024-12-19 01:27:03 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sb2frontend-altenar2.biahosted.com/api/widget/GetEventDetails?culture=cs-CZ&timezoneOffset=-60&integration=kingsbet&deviceType=1&numFormat=en-GB&countryCode=CZ&eventId=10339108> (referer: None)
# 2024-12-19 01:27:03 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.ifortuna.cz/sazeni/baseball/2-mexiko/caneros-de-los-mochis-aguilas-de-mexicali-MCZ161509399?market_filter=all> (referer: None)
# 2024-12-19 01:27:03 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.ifortuna.cz/sazeni/baseball/2-mexiko/tomateros-de-culiacan-mayos-de-navojoa-MCZ161508781?market_filter=all> (referer: None)
# 2024-12-19 01:27:03 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.ifortuna.cz/sazeni/baseball/1-australie/canberra-cavalry-melbourne-aces-MCZ158096537?market_filter=all> (referer: None)
# 2024-12-19 01:27:03 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sb2frontend-altenar2.biahosted.com/api/widget/GetEventDetails?culture=cs-CZ&timezoneOffset=-60&integration=kingsbet&deviceType=1&numFormat=en-GB&countryCode=CZ&eventId=10339101> (referer: None)
# 2024-12-19 01:27:03 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.betano.cz/api/zapas-sance/chris-landman-lok-yin-lee/59287944/?bt=99&req=la,t,s,stnf,c,mb,mbl> (referer: None)
# 2024-12-19 01:27:03 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sportapis-cz.betx.bet/SportsOfferApi/api/sport/offer/v3/match/offers?MatchId=52868911> (referer: None)
# 2024-12-19 01:27:03 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sportapis-cz.betx.bet/SportsOfferApi/api/sport/offer/v3/match/offers?MatchId=52868913> (referer: None)
# 2024-12-19 01:27:03 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.betano.cz/api/zapas-sance/canberra-cavalry-melbourne-aces/59810211/?bt=99&req=la,t,s,stnf,c,mb,mbl> (referer: None)
# 2024-12-19 01:27:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.betano.cz/api/zapas-sance/sultanes-de-monterrey-naranjeros-de-hermosillo/60402963/?bt=99&req=la,t,s,stnf,c,mb,mbl>
# {'event_url': 'https://www.betano.cz/zapas-sance/sultanes-de-monterrey-naranjeros-de-hermosillo/60402963/', 'bet_dict': {'vitez-bez-remizy': {'-': {'1': 2.25, '2': 1.6}}, 'vysledek-zapasu-s-remizou': {'-': {'1': 2.52, '0': 7.8, '2': 1.75}}}}
# 2024-12-19 01:27:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.betano.cz/api/zapas-sance/tomateros-de-culiacan-mayos-de-navojoa/60330626/?bt=99&req=la,t,s,stnf,c,mb,mbl>
# {'event_url': 'https://www.betano.cz/zapas-sance/tomateros-de-culiacan-mayos-de-navojoa/60330626/', 'bet_dict': {'vitez-bez-remizy': {'-': {'1': 1.47, '2': 2.55}}, 'vysledek-zapasu-s-remizou': {'-': {'1': 1.57, '0': 9.0, '2': 2.82}}}}
# 2024-12-19 01:27:03 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sb2frontend-altenar2.biahosted.com/api/widget/GetEventDetails?culture=cs-CZ&timezoneOffset=-60&integration=kingsbet&deviceType=1&numFormat=en-GB&countryCode=CZ&eventId=11252200> (referer: None)
# 2024-12-19 01:27:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.ifortuna.cz/sazeni/sipky/pdc-mistrovstvi-sveta/rydz-c-grbavac-r--MCZ155476764?market_filter=all> (referer: None)
# 2024-12-19 01:27:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sb2frontend-altenar2.biahosted.com/api/widget/GetEventDetails?culture=cs-CZ&timezoneOffset=-60&integration=kingsbet&deviceType=1&numFormat=en-GB&countryCode=CZ&eventId=11252230> (referer: None)
# 2024-12-19 01:27:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sportapis-cz.betx.bet/SportsOfferApi/api/sport/offer/v3/match/offers?MatchId=52868919> (referer: None)
# 2024-12-19 01:27:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sportapis-cz.betx.bet/SportsOfferApi/api/sport/offer/v3/match/offers?MatchId=52868917> (referer: None)
# 2024-12-19 01:27:04 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sb2frontend-altenar2.biahosted.com/api/widget/GetEventDetails?culture=cs-CZ&timezoneOffset=-60&integration=kingsbet&deviceType=1&numFormat=en-GB&countryCode=CZ&eventId=10354195>
# {'event_url': 'https://www.kingsbet.cz/sport?page=event&eventId=10354195', 'bet_dict': {'vitez-bez-remizy': {'-': {'1': -1.0, '2': -1.0}}, 'vysledek-zapasu-s-remizou': {'-': {'1': 1.5455, '0': 9.5, '2': 3.1429}}}}
# 2024-12-19 01:27:04 [scrapy.core.engine] DEBUG: Crawled (200) <POST https://www.fbet.cz/api/web/v1/offer/full_offer> (referer: None)
# 2024-12-19 01:27:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sportapis-cz.betx.bet/SportsOfferApi/api/sport/offer/v3/match/offers?MatchId=53069321> (referer: None)
# 2024-12-19 01:27:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sb2frontend-altenar2.biahosted.com/api/widget/GetEventDetails?culture=cs-CZ&timezoneOffset=-60&integration=kingsbet&deviceType=1&numFormat=en-GB&countryCode=CZ&eventId=11295137> (referer: None)
# 2024-12-19 01:27:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sb2frontend-altenar2.biahosted.com/api/widget/GetEventDetails?culture=cs-CZ&timezoneOffset=-60&integration=kingsbet&deviceType=1&numFormat=en-GB&countryCode=CZ&eventId=11305757> (referer: None)
# 2024-12-19 01:27:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sb2frontend-altenar2.biahosted.com/api/widget/GetEventDetails?culture=cs-CZ&timezoneOffset=-60&integration=kingsbet&deviceType=1&numFormat=en-GB&countryCode=CZ&eventId=11252139> (referer: None)
# 2024-12-19 01:27:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.betano.cz/api/zapas-sance/martin-lukeman-nitin-kumar/59287955/?bt=99&req=la,t,s,stnf,c,mb,mbl> (referer: None)
# 2024-12-19 01:27:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.betano.cz/api/zapas-sance/mensur-suljovic-matthew-campbell/59286359/?bt=99&req=la,t,s,stnf,c,mb,mbl> (referer: None)
# 2024-12-19 01:27:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.betano.cz/api/zapas-sance/scott-williams-niko-springer/59288032/?bt=99&req=la,t,s,stnf,c,mb,mbl> (referer: None)
# 2024-12-19 01:27:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.ifortuna.cz/sazeni/sipky/pdc-mistrovstvi-sveta/kenny-n-buntz-s--MCZ155476785?market_filter=all> (referer: None)
# 2024-12-19 01:27:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.ifortuna.cz/sazeni/sipky/pdc-mistrovstvi-sveta/lukeman-m-kumar-n--MCZ155476767?market_filter=all> (referer: None)
# 2024-12-19 01:27:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.ifortuna.cz/sazeni/sipky/pdc-mistrovstvi-sveta/clemens-g-owen-r--MCZ161066779?market_filter=all> (referer: None)
# 2024-12-19 01:27:04 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sb2frontend-altenar2.biahosted.com/api/widget/GetEventDetails?culture=cs-CZ&timezoneOffset=-60&integration=kingsbet&deviceType=1&numFormat=en-GB&countryCode=CZ&eventId=11048953>
# {'event_url': 'https://www.kingsbet.cz/sport?page=event&eventId=11048953', 'bet_dict': {'vitez-bez-remizy': {'-': {'1': -1.0, '2': -1.0}}, 'vysledek-zapasu-s-remizou': {'-': {'1': 1.1539, '0': 13.0, '2': 6.0}}}}
# 2024-12-19 01:27:04 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.betano.cz/api/zapas-sance/algodonerose-guasave-yaquis-de-obregon/60402930/?bt=99&req=la,t,s,stnf,c,mb,mbl>
# {'event_url': 'https://www.betano.cz/zapas-sance/algodonerose-guasave-yaquis-de-obregon/60402930/', 'bet_dict': {'vitez-bez-remizy': {'-': {'1': 1.72, '2': 2.05}}, 'vysledek-zapasu-s-remizou': {'-': {'1': 1.91, '0': 7.2, '2': 2.3}}}}
# 2024-12-19 01:27:04 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.betano.cz/api/zapas-sance/caneros-de-los-mochis-aguilas-de-mexicali/60402941/?bt=99&req=la,t,s,stnf,c,mb,mbl>
# {'event_url': 'https://www.betano.cz/zapas-sance/caneros-de-los-mochis-aguilas-de-mexicali/60402941/', 'bet_dict': {'vitez-bez-remizy': {'-': {'1': 1.55, '2': 2.37}}, 'vysledek-zapasu-s-remizou': {'-': {'1': 1.65, '0': 8.5, '2': 2.65}}}}
# 2024-12-19 01:27:04 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sb2frontend-altenar2.biahosted.com/api/widget/GetEventDetails?culture=cs-CZ&timezoneOffset=-60&integration=kingsbet&deviceType=1&numFormat=en-GB&countryCode=CZ&eventId=10339108>
# {'event_url': 'https://www.kingsbet.cz/sport?page=event&eventId=10339108', 'bet_dict': {'vitez-bez-remizy': {'-': {'1': -1.0, '2': -1.0}}, 'vysledek-zapasu-s-remizou': {'-': {'1': 1.7143, '0': 9.0, '2': 2.6667}}}}
# 2024-12-19 01:27:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.betano.cz/api/zapas-sance/nick-kenny-stowe-buntz/59287754/?bt=99&req=la,t,s,stnf,c,mb,mbl> (referer: None)
# 2024-12-19 01:27:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sb2frontend-altenar2.biahosted.com/api/widget/GetEventDetails?culture=cs-CZ&timezoneOffset=-60&integration=kingsbet&deviceType=1&numFormat=en-GB&countryCode=CZ&eventId=11084567> (referer: None)
# 2024-12-19 01:27:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sg-content-engage-prod.sazka.cz/content-service/api/v1/q/events-by-ids?eventIds=1912403&includeChildMarkets=true&includeCollections=true&includePriceHistory=false&includeCommentary=false&includeIncidents=false&includeRace=false&includeMedia=false&includePools=false&includeNonFixedOdds=false> (referer: None)
# 2024-12-19 01:27:04 [scrapy.core.engine] DEBUG: Crawled (200) <POST https://sport.synottip.cz/WebServices/Api/SportsBettingService.svc/GetWebStandardEventExt> (referer: None)
# 2024-12-19 01:27:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.betano.cz/api/zapas-sance/charros-de-jalisco-venados-de-mazatlan/60353362/?bt=99&req=la,t,s,stnf,c,mb,mbl> (referer: None)
# 2024-12-19 01:27:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.ifortuna.cz/sazeni/baseball/2-mexiko/monterrey-naranjeros-de-hermosillo-MCZ161507974?market_filter=all> (referer: None)
# 2024-12-19 01:27:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.betano.cz/api/zapas-sance/gabriel-clemens-robert-owen/60338719/?bt=99&req=la,t,s,stnf,c,mb,mbl> (referer: None)
# 2024-12-19 01:27:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sb2frontend-altenar2.biahosted.com/api/widget/GetEventDetails?culture=cs-CZ&timezoneOffset=-60&integration=kingsbet&deviceType=1&numFormat=en-GB&countryCode=CZ&eventId=11048954> (referer: None)
# 2024-12-19 01:27:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sb2frontend-altenar2.biahosted.com/api/widget/GetEventDetails?culture=cs-CZ&timezoneOffset=-60&integration=kingsbet&deviceType=1&numFormat=en-GB&countryCode=CZ&eventId=11048957> (referer: None)
# 2024-12-19 01:27:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sb2frontend-altenar2.biahosted.com/api/widget/GetEventDetails?culture=cs-CZ&timezoneOffset=-60&integration=kingsbet&deviceType=1&numFormat=en-GB&countryCode=CZ&eventId=10383614> (referer: None)
# 2024-12-19 01:27:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sportapis-cz.betx.bet/SportsOfferApi/api/sport/offer/v3/match/offers?MatchId=55697929> (referer: None)
# 2024-12-19 01:27:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sportapis-cz.betx.bet/SportsOfferApi/api/sport/offer/v3/match/offers?MatchId=55697921> (referer: None)
# 2024-12-19 01:27:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sg-content-engage-prod.sazka.cz/content-service/api/v1/q/events-by-ids?eventIds=1914150&includeChildMarkets=true&includeCollections=true&includePriceHistory=false&includeCommentary=false&includeIncidents=false&includeRace=false&includeMedia=false&includePools=false&includeNonFixedOdds=false> (referer: None)
# 2024-12-19 01:27:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sportapis-cz.betx.bet/SportsOfferApi/api/sport/offer/v3/match/offers?MatchId=52494495> (referer: None)
# 2024-12-19 01:27:04 [scrapy.core.engine] DEBUG: Crawled (200) <POST https://sport.synottip.cz/WebServices/Api/SportsBettingService.svc/GetWebStandardEventExt> (referer: None)
# 2024-12-19 01:27:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sg-content-engage-prod.sazka.cz/content-service/api/v1/q/events-by-ids?eventIds=1914149&includeChildMarkets=true&includeCollections=true&includePriceHistory=false&includeCommentary=false&includeIncidents=false&includeRace=false&includeMedia=false&includePools=false&includeNonFixedOdds=false> (referer: None)
# 2024-12-19 01:27:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sg-content-engage-prod.sazka.cz/content-service/api/v1/q/events-by-ids?eventIds=1914156&includeChildMarkets=true&includeCollections=true&includePriceHistory=false&includeCommentary=false&includeIncidents=false&includeRace=false&includeMedia=false&includePools=false&includeNonFixedOdds=false> (referer: None)
# 2024-12-19 01:27:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sg-content-engage-prod.sazka.cz/content-service/api/v1/q/events-by-ids?eventIds=1879141&includeChildMarkets=true&includeCollections=true&includePriceHistory=false&includeCommentary=false&includeIncidents=false&includeRace=false&includeMedia=false&includePools=false&includeNonFixedOdds=false> (referer: None)
# 2024-12-19 01:27:04 [scrapy.core.engine] DEBUG: Crawled (200) <POST https://sport.synottip.cz/WebServices/Api/SportsBettingService.svc/GetWebStandardEventExt> (referer: None)
# 2024-12-19 01:27:04 [scrapy.core.engine] DEBUG: Crawled (200) <POST https://sport.synottip.cz/WebServices/Api/SportsBettingService.svc/GetWebStandardEventExt> (referer: None)
# 2024-12-19 01:27:04 [scrapy.core.engine] DEBUG: Crawled (200) <POST https://sport.synottip.cz/WebServices/Api/SportsBettingService.svc/GetWebStandardEventExt> (referer: None)
# 2024-12-19 01:27:04 [scrapy.core.engine] DEBUG: Crawled (200) <POST https://sport.synottip.cz/WebServices/Api/SportsBettingService.svc/GetWebStandardEventExt> (referer: None)
# 2024-12-19 01:27:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sg-content-engage-prod.sazka.cz/content-service/api/v1/q/events-by-ids?eventIds=1906045&includeChildMarkets=true&includeCollections=true&includePriceHistory=false&includeCommentary=false&includeIncidents=false&includeRace=false&includeMedia=false&includePools=false&includeNonFixedOdds=false> (referer: None)
# 2024-12-19 01:27:04 [scrapy.core.engine] DEBUG: Crawled (200) <POST https://sport.synottip.cz/WebServices/Api/SportsBettingService.svc/GetWebStandardEventExt> (referer: None)
# 2024-12-19 01:27:04 [scrapy.core.engine] DEBUG: Crawled (200) <POST https://sport.synottip.cz/WebServices/Api/SportsBettingService.svc/GetWebStandardEventExt> (referer: None)
# 2024-12-19 01:27:04 [scrapy.core.engine] DEBUG: Crawled (200) <POST https://sport.synottip.cz/WebServices/Api/SportsBettingService.svc/GetWebStandardEventExt> (referer: None)
# 2024-12-19 01:27:04 [scrapy.core.engine] DEBUG: Crawled (200) <POST https://sport.synottip.cz/WebServices/Api/SportsBettingService.svc/GetWebStandardEventExt> (referer: None)
# 2024-12-19 01:27:04 [scrapy.core.engine] DEBUG: Crawled (200) <POST https://sport.synottip.cz/WebServices/Api/SportsBettingService.svc/GetWebStandardEventExt> (referer: None)
# 2024-12-19 01:27:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sg-content-engage-prod.sazka.cz/content-service/api/v1/q/events-by-ids?eventIds=1910482&includeChildMarkets=true&includeCollections=true&includePriceHistory=false&includeCommentary=false&includeIncidents=false&includeRace=false&includeMedia=false&includePools=false&includeNonFixedOdds=false> (referer: None)
# 2024-12-19 01:27:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sg-content-engage-prod.sazka.cz/content-service/api/v1/q/events-by-ids?eventIds=1914148&includeChildMarkets=true&includeCollections=true&includePriceHistory=false&includeCommentary=false&includeIncidents=false&includeRace=false&includeMedia=false&includePools=false&includeNonFixedOdds=false> (referer: None)
# 2024-12-19 01:27:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sg-content-engage-prod.sazka.cz/content-service/api/v1/q/events-by-ids?eventIds=1914152&includeChildMarkets=true&includeCollections=true&includePriceHistory=false&includeCommentary=false&includeIncidents=false&includeRace=false&includeMedia=false&includePools=false&includeNonFixedOdds=false> (referer: None)
# 2024-12-19 01:27:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sg-content-engage-prod.sazka.cz/content-service/api/v1/q/events-by-ids?eventIds=1914151&includeChildMarkets=true&includeCollections=true&includePriceHistory=false&includeCommentary=false&includeIncidents=false&includeRace=false&includeMedia=false&includePools=false&includeNonFixedOdds=false> (referer: None)
# 2024-12-19 01:27:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.betano.cz/api/zapas-sance/shane-hayward-ivan-springborg-poulsen/60412746/?bt=99&req=la,t,s,stnf,c,mb,mbl> (referer: None)
# 2024-12-19 01:27:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sportapis-cz.betx.bet/SportsOfferApi/api/sport/offer/v3/match/offers?MatchId=55808485> (referer: None)
# 2024-12-19 01:27:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sb2frontend-altenar2.biahosted.com/api/widget/GetEventDetails?culture=cs-CZ&timezoneOffset=-60&integration=kingsbet&deviceType=1&numFormat=en-GB&countryCode=CZ&eventId=11295135> (referer: None)
# 2024-12-19 01:27:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.ifortuna.cz/sazeni/sipky/adc-global-championship/hayward-s-springborg-poulsen-i--MCZ161530926?market_filter=all> (referer: None)
# 2024-12-19 01:27:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.betano.cz/api/zapas-sance/michael-smith-kevin-doets/60354559/?bt=99&req=la,t,s,stnf,c,mb,mbl> (referer: None)
# 2024-12-19 01:27:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.ifortuna.cz/sazeni/hazena/nemecko-pohar-muzi/rn-lowen-eisenach-MCZ154569639?market_filter=all> (referer: None)
# 2024-12-19 01:27:04 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.ifortuna.cz/sazeni/baseball/2-mexiko/caneros-de-los-mochis-aguilas-de-mexicali-MCZ161509399?market_filter=all>
# {'event_url': 'https://www.ifortuna.cz/sazeni/baseball/2-mexiko/caneros-de-los-mochis-aguilas-de-mexicali-MCZ161509399', 'bet_dict': {'vitez-bez-remizy': {'-': {'1': -1.0, '2': -1.0}}, 'vysledek-zapasu-s-remizou': {'-': {'1': 1.63, '0': 9.4, '2': 2.65}}}}
# 2024-12-19 01:27:04 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.ifortuna.cz/sazeni/baseball/2-mexiko/tomateros-de-culiacan-mayos-de-navojoa-MCZ161508781?market_filter=all>
# {'event_url': 'https://www.ifortuna.cz/sazeni/baseball/2-mexiko/tomateros-de-culiacan-mayos-de-navojoa-MCZ161508781', 'bet_dict': {'vitez-bez-remizy': {'-': {'1': -1.0, '2': -1.0}}, 'vysledek-zapasu-s-remizou': {'-': {'1': 1.56, '0': 9.6, '2': 2.85}}}}
# 2024-12-19 01:27:04 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.ifortuna.cz/sazeni/baseball/1-australie/canberra-cavalry-melbourne-aces-MCZ158096537?market_filter=all>
# {'event_url': 'https://www.ifortuna.cz/sazeni/baseball/1-australie/canberra-cavalry-melbourne-aces-MCZ158096537', 'bet_dict': {'vitez-bez-remizy': {'-': {'1': -1.0, '2': -1.0}}, 'vysledek-zapasu-s-remizou': {'-': {'1': -1.0, '0': -1.0, '2': -1.0}}}}
# 2024-12-19 01:27:04 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sb2frontend-altenar2.biahosted.com/api/widget/GetEventDetails?culture=cs-CZ&timezoneOffset=-60&integration=kingsbet&deviceType=1&numFormat=en-GB&countryCode=CZ&eventId=10339101>
# {'event_url': 'https://www.kingsbet.cz/sport?page=event&eventId=10339101', 'bet_dict': {'vitez-bez-remizy': {'-': {'1': -1.0, '2': -1.0}}, 'vysledek-zapasu-s-remizou': {'-': {'1': 1.3, '0': 11.0, '2': 4.75}}}}
# 2024-12-19 01:27:04 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.betano.cz/api/zapas-sance/chris-landman-lok-yin-lee/59287944/?bt=99&req=la,t,s,stnf,c,mb,mbl>
# {'event_url': 'https://www.betano.cz/zapas-sance/chris-landman-lok-yin-lee/59287944/', 'bet_dict': {'vitez-bez-remizy': {'-': {'1': 1.13, '2': 5.7}}, 'vysledek-zapasu-s-remizou': {'-': {'1': -1.0, '0': -1.0, '2': -1.0}}}}
# 2024-12-19 01:27:04 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sportapis-cz.betx.bet/SportsOfferApi/api/sport/offer/v3/match/offers?MatchId=52868911>
# {'event_url': 'https://bet-x.cz/cs/sports-betting/offer/baseball?match=52868911', 'bet_dict': {'vitez-bez-remizy': {'-': {'1': 2.24, '2': 1.58}}, 'vysledek-zapasu-s-remizou': {'-': {'1': 2.49, '0': 8.4, '2': 1.7}}}}
# 2024-12-19 01:27:04 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sportapis-cz.betx.bet/SportsOfferApi/api/sport/offer/v3/match/offers?MatchId=52868913>
# ...
# 2024-12-19 01:30:12 [scrapy.core.engine] DEBUG: Crawled (200) <POST https://sport.synottip.cz/WebServices/Api/SportsBettingService.svc/GetWebStandardEventExt> (referer: None)
# 2024-12-19 01:30:12 [scrapy.core.engine] DEBUG: Crawled (200) <POST https://sport.synottip.cz/WebServices/Api/SportsBettingService.svc/GetWebStandardEventExt> (referer: None)
# 2024-12-19 01:30:12 [scrapy.core.engine] DEBUG: Crawled (200) <POST https://sport.synottip.cz/WebServices/Api/SportsBettingService.svc/GetWebStandardEventExt> (referer: None)
# 2024-12-19 01:30:12 [scrapy.core.engine] DEBUG: Crawled (200) <POST https://sport.synottip.cz/WebServices/Api/SportsBettingService.svc/GetWebStandardEventExt> (referer: None)
# 2024-12-19 01:30:12 [scrapy.core.engine] DEBUG: Crawled (200) <POST https://sport.synottip.cz/WebServices/Api/SportsBettingService.svc/GetWebStandardEventExt> (referer: None)
# 2024-12-19 01:30:12 [scrapy.core.engine] DEBUG: Crawled (200) <POST https://sport.synottip.cz/WebServices/Api/SportsBettingService.svc/GetWebStandardEventExt> (referer: None)
# 2024-12-19 01:30:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sport.synottip.cz/WebServices/Api/SportsBettingService.svc/GetWebStandardEventExt>
# {'event_url': 'https://sport.synottip.cz/zapasy/20/2478712cxx8379/244260421?categoryId=20', 'bet_dict': {'vitez-bez-remizy': {'-': {'1': 1.74, '2': 1.9}}, 'vysledek-zapasu-s-remizou': {'-': {'1': -1.0, '0': -1.0, '2': -1.0}}}}
# 2024-12-19 01:30:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sport.synottip.cz/WebServices/Api/SportsBettingService.svc/GetWebStandardEventExt>
# {'event_url': 'https://sport.synottip.cz/zapasy/20/2478717cxx8379/244282971?categoryId=20', 'bet_dict': {'vitez-bez-remizy': {'-': {'1': 2.4, '2': 1.47}}, 'vysledek-zapasu-s-remizou': {'-': {'1': -1.0, '0': -1.0, '2': -1.0}}}}
# 2024-12-19 01:30:12 [scrapy.core.engine] DEBUG: Crawled (200) <POST https://sport.synottip.cz/WebServices/Api/SportsBettingService.svc/GetWebStandardEventExt> (referer: None)
# 2024-12-19 01:30:12 [scrapy.core.engine] DEBUG: Crawled (200) <POST https://sport.synottip.cz/WebServices/Api/SportsBettingService.svc/GetWebStandardEventExt> (referer: None)
# 2024-12-19 01:30:12 [scrapy.core.engine] DEBUG: Crawled (200) <POST https://sport.synottip.cz/WebServices/Api/SportsBettingService.svc/GetWebStandardEventExt> (referer: None)
# 2024-12-19 01:30:12 [scrapy.core.engine] DEBUG: Crawled (200) <POST https://sport.synottip.cz/WebServices/Api/SportsBettingService.svc/GetWebStandardEventExt> (referer: None)
# 2024-12-19 01:30:12 [scrapy.core.engine] DEBUG: Crawled (200) <POST https://sport.synottip.cz/WebServices/Api/SportsBettingService.svc/GetWebStandardEventExt> (referer: None)
# 2024-12-19 01:30:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sport.synottip.cz/WebServices/Api/SportsBettingService.svc/GetWebStandardEventExt>
# {'event_url': 'https://sport.synottip.cz/zapasy/20/2478726cxx8379/244260535?categoryId=20', 'bet_dict': {'vitez-bez-remizy': {'-': {'1': 3.27, '2': 1.26}}, 'vysledek-zapasu-s-remizou': {'-': {'1': -1.0, '0': -1.0, '2': -1.0}}}}
# 2024-12-19 01:30:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sport.synottip.cz/WebServices/Api/SportsBettingService.svc/GetWebStandardEventExt>
# {'event_url': 'https://sport.synottip.cz/zapasy/20/2478728cxx8379/244282998?categoryId=20', 'bet_dict': {'vitez-bez-remizy': {'-': {'1': 1.55, '2': 2.2}}, 'vysledek-zapasu-s-remizou': {'-': {'1': -1.0, '0': -1.0, '2': -1.0}}}}
# 2024-12-19 01:30:13 [scrapy.core.engine] DEBUG: Crawled (200) <POST https://sport.synottip.cz/WebServices/Api/SportsBettingService.svc/GetWebStandardEventExt> (referer: None)
# 2024-12-19 01:30:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sport.synottip.cz/WebServices/Api/SportsBettingService.svc/GetWebStandardEventExt>
# {'event_url': 'https://sport.synottip.cz/zapasy/20/2478733cxx8379/244261319?categoryId=20', 'bet_dict': {'vitez-bez-remizy': {'-': {'1': 2.05, '2': 1.63}}, 'vysledek-zapasu-s-remizou': {'-': {'1': -1.0, '0': -1.0, '2': -1.0}}}}
# 2024-12-19 01:30:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sport.synottip.cz/WebServices/Api/SportsBettingService.svc/GetWebStandardEventExt>
# {'event_url': 'https://sport.synottip.cz/zapasy/20/2478739cxx8379/244260554?categoryId=20', 'bet_dict': {'vitez-bez-remizy': {'-': {'1': 1.63, '2': 2.05}}, 'vysledek-zapasu-s-remizou': {'-': {'1': -1.0, '0': -1.0, '2': -1.0}}}}
# 2024-12-19 01:30:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sport.synottip.cz/WebServices/Api/SportsBettingService.svc/GetWebStandardEventExt>
# {'event_url': 'https://sport.synottip.cz/zapasy/20/2478748cxx8379/244261132?categoryId=20', 'bet_dict': {'vitez-bez-remizy': {'-': {'1': 1.82, '2': 1.82}}, 'vysledek-zapasu-s-remizou': {'-': {'1': -1.0, '0': -1.0, '2': -1.0}}}}
# 2024-12-19 01:30:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sport.synottip.cz/WebServices/Api/SportsBettingService.svc/GetWebStandardEventExt>
# {'event_url': 'https://sport.synottip.cz/zapasy/20/2478743cxx8379/244260517?categoryId=20', 'bet_dict': {'vitez-bez-remizy': {'-': {'1': 1.77, '2': 1.87}}, 'vysledek-zapasu-s-remizou': {'-': {'1': -1.0, '0': -1.0, '2': -1.0}}}}
# 2024-12-19 01:30:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sport.synottip.cz/WebServices/Api/SportsBettingService.svc/GetWebStandardEventExt>
# {'event_url': 'https://sport.synottip.cz/zapasy/20/2478755cxx8379/244261096?categoryId=20', 'bet_dict': {'vitez-bez-remizy': {'-': {'1': 1.77, '2': 1.87}}, 'vysledek-zapasu-s-remizou': {'-': {'1': -1.0, '0': -1.0, '2': -1.0}}}}
# 2024-12-19 01:30:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sport.synottip.cz/WebServices/Api/SportsBettingService.svc/GetWebStandardEventExt>
# {'event_url': 'https://sport.synottip.cz/zapasy/20/2478749cxx8379/244338934?categoryId=20', 'bet_dict': {'vitez-bez-remizy': {'-': {'1': 1.51, '2': 2.29}}, 'vysledek-zapasu-s-remizou': {'-': {'1': -1.0, '0': -1.0, '2': -1.0}}}}
# 2024-12-19 01:30:13 [scrapy.core.engine] DEBUG: Crawled (200) <POST https://sport.synottip.cz/WebServices/Api/SportsBettingService.svc/GetWebStandardEventExt> (referer: None)
# 2024-12-19 01:30:13 [scrapy.core.engine] DEBUG: Crawled (200) <POST https://sport.synottip.cz/WebServices/Api/SportsBettingService.svc/GetWebStandardEventExt> (referer: None)
# 2024-12-19 01:30:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sport.synottip.cz/WebServices/Api/SportsBettingService.svc/GetWebStandardEventExt>
# {'event_url': 'https://sport.synottip.cz/zapasy/20/2478744cxx8379/244260582?categoryId=20', 'bet_dict': {'vitez-bez-remizy': {'-': {'1': 2.2, '2': 1.55}}, 'vysledek-zapasu-s-remizou': {'-': {'1': -1.0, '0': -1.0, '2': -1.0}}}}
# 2024-12-19 01:30:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sport.synottip.cz/WebServices/Api/SportsBettingService.svc/GetWebStandardEventExt>
# {'event_url': 'https://sport.synottip.cz/zapasy/20/2478740cxx8379/244260453?categoryId=20', 'bet_dict': {'vitez-bez-remizy': {'-': {'1': 1.77, '2': 1.87}}, 'vysledek-zapasu-s-remizou': {'-': {'1': -1.0, '0': -1.0, '2': -1.0}}}}
# 2024-12-19 01:30:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sport.synottip.cz/WebServices/Api/SportsBettingService.svc/GetWebStandardEventExt>
# {'event_url': 'https://sport.synottip.cz/zapasy/20/2478756cxx8379/244260620?categoryId=20', 'bet_dict': {'vitez-bez-remizy': {'-': {'1': 1.7, '2': 1.96}}, 'vysledek-zapasu-s-remizou': {'-': {'1': -1.0, '0': -1.0, '2': -1.0}}}}
# 2024-12-19 01:30:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sport.synottip.cz/WebServices/Api/SportsBettingService.svc/GetWebStandardEventExt>
# {'event_url': 'https://sport.synottip.cz/zapasy/20/2478746cxx8379/244338917?categoryId=20', 'bet_dict': {'vitez-bez-remizy': {'-': {'1': 1.7, '2': 1.96}}, 'vysledek-zapasu-s-remizou': {'-': {'1': -1.0, '0': -1.0, '2': -1.0}}}}
# 2024-12-19 01:30:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sport.synottip.cz/WebServices/Api/SportsBettingService.svc/GetWebStandardEventExt>
# {'event_url': 'https://sport.synottip.cz/zapasy/20/2478759cxx8379/244260642?categoryId=20', 'bet_dict': {'vitez-bez-remizy': {'-': {'1': 1.84, '2': 1.8}}, 'vysledek-zapasu-s-remizou': {'-': {'1': -1.0, '0': -1.0, '2': -1.0}}}}
# 2024-12-19 01:30:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sport.synottip.cz/WebServices/Api/SportsBettingService.svc/GetWebStandardEventExt>
# {'event_url': 'https://sport.synottip.cz/zapasy/20/2478751cxx8379/244260389?categoryId=20', 'bet_dict': {'vitez-bez-remizy': {'-': {'1': 3.02, '2': 1.3}}, 'vysledek-zapasu-s-remizou': {'-': {'1': -1.0, '0': -1.0, '2': -1.0}}}}
# 2024-12-19 01:30:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sport.synottip.cz/WebServices/Api/SportsBettingService.svc/GetWebStandardEventExt>
# {'event_url': 'https://sport.synottip.cz/zapasy/20/2478766cxx8379/244260380?categoryId=20', 'bet_dict': {'vitez-bez-remizy': {'-': {'1': 1.96, '2': 1.7}}, 'vysledek-zapasu-s-remizou': {'-': {'1': -1.0, '0': -1.0, '2': -1.0}}}}
# 2024-12-19 01:30:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sport.synottip.cz/WebServices/Api/SportsBettingService.svc/GetWebStandardEventExt>
# {'event_url': 'https://sport.synottip.cz/zapasy/20/2478760cxx8379/244260405?categoryId=20', 'bet_dict': {'vitez-bez-remizy': {'-': {'1': 1.63, '2': 2.05}}, 'vysledek-zapasu-s-remizou': {'-': {'1': -1.0, '0': -1.0, '2': -1.0}}}}
# 2024-12-19 01:30:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sport.synottip.cz/WebServices/Api/SportsBettingService.svc/GetWebStandardEventExt>
# {'event_url': 'https://sport.synottip.cz/zapasy/20/2478767cxx8379/244260437?categoryId=20', 'bet_dict': {'vitez-bez-remizy': {'-': {'1': 2.14, '2': 1.58}}, 'vysledek-zapasu-s-remizou': {'-': {'1': -1.0, '0': -1.0, '2': -1.0}}}}
# 2024-12-19 01:30:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sport.synottip.cz/WebServices/Api/SportsBettingService.svc/GetWebStandardEventExt>
# {'event_url': 'https://sport.synottip.cz/zapasy/20/2478747cxx8379/244260693?categoryId=20', 'bet_dict': {'vitez-bez-remizy': {'-': {'1': 2.4, '2': 1.47}}, 'vysledek-zapasu-s-remizou': {'-': {'1': -1.0, '0': -1.0, '2': -1.0}}}}
# 2024-12-19 01:30:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sport.synottip.cz/WebServices/Api/SportsBettingService.svc/GetWebStandardEventExt>
# {'event_url': 'https://sport.synottip.cz/zapasy/20/2478722cxx8379/244260730?categoryId=20', 'bet_dict': {'vitez-bez-remizy': {'-': {'1': 1.52, '2': 2.25}}, 'vysledek-zapasu-s-remizou': {'-': {'1': -1.0, '0': -1.0, '2': -1.0}}}}
# 2024-12-19 01:30:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sport.synottip.cz/WebServices/Api/SportsBettingService.svc/GetWebStandardEventExt>
# {'event_url': 'https://sport.synottip.cz/zapasy/20/2478741cxx8379/244260714?categoryId=20', 'bet_dict': {'vitez-bez-remizy': {'-': {'1': 1.63, '2': 2.05}}, 'vysledek-zapasu-s-remizou': {'-': {'1': -1.0, '0': -1.0, '2': -1.0}}}}
# 2024-12-19 01:30:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sport.synottip.cz/WebServices/Api/SportsBettingService.svc/GetWebStandardEventExt>
# {'event_url': 'https://sport.synottip.cz/zapasy/20/2478773cxx8379/244283031?categoryId=20', 'bet_dict': {'vitez-bez-remizy': {'-': {'1': 1.47, '2': 2.4}}, 'vysledek-zapasu-s-remizou': {'-': {'1': -1.0, '0': -1.0, '2': -1.0}}}}
# 2024-12-19 01:30:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sport.synottip.cz/WebServices/Api/SportsBettingService.svc/GetWebStandardEventExt>
# {'event_url': 'https://sport.synottip.cz/zapasy/20/2478731cxx8379/244261192?categoryId=20', 'bet_dict': {'vitez-bez-remizy': {'-': {'1': 2.4, '2': 1.47}}, 'vysledek-zapasu-s-remizou': {'-': {'1': -1.0, '0': -1.0, '2': -1.0}}}}
# 2024-12-19 01:30:13 [scrapy.core.engine] DEBUG: Crawled (200) <POST https://sport.synottip.cz/WebServices/Api/SportsBettingService.svc/GetWebStandardEventExt> (referer: None)
# 2024-12-19 01:30:13 [scrapy.core.engine] DEBUG: Crawled (200) <POST https://sport.synottip.cz/WebServices/Api/SportsBettingService.svc/GetWebStandardEventExt> (referer: None)
# 2024-12-19 01:30:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sport.synottip.cz/WebServices/Api/SportsBettingService.svc/GetWebStandardEventExt>
# {'event_url': 'https://sport.synottip.cz/zapasy/20/2478770cxx8379/244260604?categoryId=20', 'bet_dict': {'vitez-bez-remizy': {'-': {'1': 1.63, '2': 2.05}}, 'vysledek-zapasu-s-remizou': {'-': {'1': -1.0, '0': -1.0, '2': -1.0}}}}
# 2024-12-19 01:30:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sport.synottip.cz/WebServices/Api/SportsBettingService.svc/GetWebStandardEventExt>
# {'event_url': 'https://sport.synottip.cz/zapasy/87/2476088cx571/243960370?categoryId=87', 'bet_dict': {'vitez-bez-remizy': {'-': {'1': 1.22, '2': 3.6}}, 'vysledek-zapasu-s-remizou': {'-': {'1': -1.0, '0': -1.0, '2': -1.0}}}}
# 2024-12-19 01:30:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sport.synottip.cz/WebServices/Api/SportsBettingService.svc/GetWebStandardEventExt>
# {'event_url': 'https://sport.synottip.cz/zapasy/20/2478758cxx8379/244260469?categoryId=20', 'bet_dict': {'vitez-bez-remizy': {'-': {'1': 1.55, '2': 2.2}}, 'vysledek-zapasu-s-remizou': {'-': {'1': -1.0, '0': -1.0, '2': -1.0}}}}
# 2024-12-19 01:30:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sport.synottip.cz/WebServices/Api/SportsBettingService.svc/GetWebStandardEventExt>
# {'event_url': 'https://sport.synottip.cz/zapasy/87/2476089cx571/243963197?categoryId=87', 'bet_dict': {'vitez-bez-remizy': {'-': {'1': 2.13, '2': 1.58}}, 'vysledek-zapasu-s-remizou': {'-': {'1': -1.0, '0': -1.0, '2': -1.0}}}}
# 2024-12-19 01:30:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sport.synottip.cz/WebServices/Api/SportsBettingService.svc/GetWebStandardEventExt>
# {'event_url': 'https://sport.synottip.cz/zapasy/14/2478123cxx1272/244206940?categoryId=14', 'bet_dict': {'vitez': {'-': {'1': 1.94, '2': 1.71}}, 'vysledek-v-zakladni-hraci-dobe': {'-': {'1': 2.56, '0': 4.03, '2': 2.17}}, 'vysledek-v-prvni-tretine': {'-': {'1': 2.92, '0': 2.58, '2': 2.63}}, 'vysledek-ve-druhe-tretine': {'-': {'1': -1.0, '0': -1.0, '2': -1.0}}, 'vysledek-ve-treti-tretine': {'-': {'1': -1.0, '0': -1.0, '2': -1.0}}, 'vice-mene-pocet-golu': {'1,5': {'vice-nez-1,5': -1.0, 'mene-nez-1,5': -1.0}}}}
# 2024-12-19 01:30:13 [scrapy.core.engine] INFO: Closing spider (finished)
# 2024-12-19 01:30:13 [scrapy.extensions.feedexport] INFO: Stored json feed (449 items) in: data/data_synottip_detail.json
# 2024-12-19 01:30:13 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 255176,
#  'downloader/request_count': 449,
#  'downloader/request_method_count/POST': 449,
#  'downloader/response_bytes': 3410878,
#  'downloader/response_count': 449,
#  'downloader/response_status_count/200': 449,
#  'elapsed_time_seconds': 192.907532,
#  'feedexport/success_count/FileFeedStorage': 1,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2024, 12, 19, 0, 30, 13, 515141, tzinfo=datetime.timezone.utc),
#  'item_scraped_count': 449,
#  'log_count/DEBUG': 5686,
#  'log_count/ERROR': 216,
#  'log_count/INFO': 294,
#  'log_count/WARNING': 10,
#  'memusage/max': 341508096,
#  'memusage/startup': 197922816,
#  'response_received_count': 449,
#  'scheduler/dequeued': 449,
#  'scheduler/dequeued/memory': 449,
#  'scheduler/enqueued': 449,
#  'scheduler/enqueued/memory': 449,
#  'start_time': datetime.datetime(2024, 12, 19, 0, 27, 0, 607609, tzinfo=datetime.timezone.utc)}
# 2024-12-19 01:30:13 [scrapy.core.engine] INFO: Spider closed (finished)
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
from collections import Counter

# Example list
numbers = [len(x) for x in list(events['bookmaker_list'])]

# Count occurrences
counts = Counter(numbers)

# Print counts for numbers 1 through 9
for num in range(1, 10):
    print(f"Number {num}: {counts[num]}")
# Out:
# Number 1: 0
# Number 2: 210
# Number 3: 121
# Number 4: 68
# Number 5: 108
# Number 6: 62
# Number 7: 40
# Number 8: 40
# Number 9: 63
